# %%
#parameters
dim = 4196
percentage = 0.5
n = dim * percentage
n=int(n)
top_pop_csv = "top_pop.csv"
collaborative_csv = "collaborative.csv"

# %%
#overwrites top_pop file writing on the first half of the rows the collaborative ratings
import csv
f1= open(top_pop_csv,'w') #top pop
csv_f1_w=csv.writer(f1)

f2 = open(collaborative_csv, 'r') #collaborative
csv_f2_r=csv.reader(f2)

count=0

for i in range(0,n):
    count+=1
    csv_f1_w.writerow(csv_f2_r.next())
    #csv_f1_r.next()

print count
f1.close()
f2.close()
# Out:
# 2098

# %%
#just a check on the result

f1 = open(top_pop, 'r')
csv_f1_r=csv.reader(f1)


count2=0

for i in csv_f1_r:
    count+=1
    print i
    
print count
f1.close()
# Out:
# ['userId', 'testItems']
# ['4', '33173 33475 31992 35300 1076']
# ['5', '33173 33475 31992 35300 1076']
# ['8', '33173 33475 31992 35300 1076']
# ['9', '33173 33475 31992 35300 1076']
# ['13', '33173 33475 31992 35300 1076']
# ['18', '33173 33475 31992 35300 1076']
# ['19', '33173 33475 31992 35300 1076']
# ['23', '33173 33475 31992 35300 1076']
# ['26', '33173 33475 31992 35300 1076']
# ['29', '33173 33475 31992 35300 1076']
# ['31', '33173 33475 31992 35300 1076']
# ['32', '33173 33475 31992 35300 1076']
# ['33', '33173 33475 31992 35300 1076']
# ['35', '33173 33475 31992 35300 1076']
# ['37', '33173 33475 31992 35300 1076']
# ['51', '33173 33475 31992 35300 1076']
# ['52', '33173 33475 31992 35300 1076']
# ['53', '33173 33475 31992 35300 1076']
# ['54', '33173 33475 31992 35300 1076']
# ['61', '33173 33475 31992 35300 1076']
# ['64', '33173 33475 31992 35300 1076']
# ['69', '33173 33475 31992 35300 1076']
# ['76', '33173 33475 31992 35300 1076']
# ...
